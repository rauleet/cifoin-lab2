# %% [markdown]
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/05/logo-upv-horizontal.png)
# ![PIC UPV PERTE Chip Chair Logo](https://www.pic-chair.upv.es/wp-content/uploads/2024/06/logos-perte-chip-1024x119.png)
#
#
# # Laboratory 2.0. Coupler Design

# %% [markdown]
# ## 0. Imports

# %% [markdown]
# ### 0.1. General libraries

# %% [markdown]
# **Run only the first time you execute this Jupyter Notebook**
# You can delete this command lines after succesfully installing this tools

# %%
#!sudo apt-get install libgomp1
#!sudo apt-get install libxft2
#!sudo apt-get install libglu1

# %% [markdown]
# Run everytime you start to execute this Jupyter Notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

import tidy3d as td
import gplugins.tidy3d as gt

nm = 1e-3
wavelength = np.linspace(1500, 1600) * nm
f = td.C_0 / wavelength

# %% [markdown]
# ### 0.2. Functions by us

# %%
from upvfab_design_tools import MMI_EME, DC_EME

# %% [markdown]
# ## LO.1. Directional coupler cross-section in GDSFactory
#
# ### 1.1. Materials

# %%
nitride_complex = td.material_library["Si3N4"]["Luke2015PMLStable"].eps_model(f)
nitride_index, nitride_k = td.Medium.eps_complex_to_nk(nitride_complex)
box_complex = td.material_library["SiO2"]["Horiba"].eps_model(f)
box_index, box_k = td.Medium.eps_complex_to_nk(box_complex)

# %% [markdown]
# ### 1.2. Cross-Section Definition
#
# In GDSFactory - Tidy3d modesolver we have another function to easily define the Cross-Section of a Directional Coupler: [gt.modes.WaveguideCoupler()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html). It implements the deep (rib) and shallow (ridge) directional coupler waveguides cross-section, using as input parameters all the dimensions of the waveguide cores and also the distance between them (gap).

# %%
lambda_c = 1.55

dcoupler_cs = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.2, 1.2), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=600 * nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)

dcoupler_cs.plot_index()

# %% [markdown]
# ### 1.3. Simulations
#
# #### 1.3.1. Parameters
#
# As before, we can calculate the effective index (n_eff), TE and TM fraction for this cross-section using the already implemented class methods: .n_eff, .fraction_te and .fraction_tm. Remember that we will calculate one effective index for each mode (up to num_modes)

# %%
dcoupler_neff = dcoupler_cs.n_eff
print(dcoupler_neff)
# Out:
# 2026-04-29 17:42:32.166 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbc1bb971a882eda.npz.
# [1.60942484+1.02849974e-04j 1.60116589+9.83178135e-05j
#  1.53540293+1.77367472e-04j 1.52057329+1.77190584e-04j]

# %%
dcoupler_cs.fraction_te
# Out:
# array([0.994898  , 0.99527537, 0.00888064, 0.01130183])

# %% [markdown]
# $Explicación 1 $:
# Para este caso se puede ver como el modo 0 y el modo 1 son modos TE mientras que el 2 y el 3 son modos TM

# %%
dcoupler_cs.fraction_tm
# Out:
# array([0.005102  , 0.00472463, 0.99111936, 0.98869817])

# %% [markdown]
# #### 1.3.2. Plots
#
# We could also plot the fields for each mode identified. Remember: the 'Ex' field component corresponds to TE modes, while the 'Ey' field component corresponds to TM modes. In the case of the directional coupler, the even and odd modes play a key role in facilitating energy exchange between the waveguides. Now, let's plot and analyze their behavior.

# %%
dcoupler_cs.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %% [markdown]
# Este modo corresponde al modo TE 0, el cual presenta los máximos dentro de las guías por eso decimos que es el modo simétrico, ya que este no tenia un nulo al medio

# %%
dcoupler_cs.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# Este modo corresponde al modo TE 1 que representa la forma antisimétrica en la guia ya que en una guía está de color rojo y en la otra de color azul. Esto nos quiere decir que una guía es positiva, mientras que la otra gúia es negativa el modo.

# %%
dcoupler_cs.plot_field(mode_index=2 , # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# Este modo corresponde al Modo TM 0, que tiene un caracter simétrico, se pueden ver como los núcleos son donde hay más potencia

# %%
dcoupler_cs.plot_field(mode_index=3, # Mode to be plotted
                          field_name='Ey', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-2.5, 2.5), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# Este modo 3 Corresponde al Modo TM1 que corresponde al modo antisimétrico ya que la potencia está invertida en cada sentido de la guía

# %% [markdown]
# #### 1.3.3. Beating or Coupling Length calculation (𝐿𝜋)
#
# The key parameter that determines the design of a directional coupler is the coupling or beating length. This length defines the total size of the coupling region required to transfer all the optical power from one waveguide to another. It is determined by the difference between the effective indices of the cross-section's odd and even modes:

# %%
# TE Modes: Modes 0 & 1
L_pi_TE = 0.5*lambda_c/(dcoupler_neff[0].real-dcoupler_neff[1].real)
print(L_pi_TE)

L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
print(L_pi_TM)
# Out:
# 93.83767536699743
# 52.260223677440635

# %% [markdown]
# Aquí se calcula la Lpi. Los modo (TE o TM) tiene su propia longitud. Esta es la longitud que hace falta para que cada guia transfiera la máxima potencia a la otra guía. Con la función de abajo se puede calcular, pero da muchos problemas.

# %% [markdown]
# GDSFactory has its own method implemented to calculate the coupling length: [.coupling_length()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.WaveguideCoupler.html)

# %%
dcoupler_cs.coupling_length()
# Out:
# array([93.83767537, 52.26022368])

# %% [markdown]
# ## LO.2. Directional coupler length and coupling coefficient
#
# The total power transferred to the output is modeled using the coupling coefficient (K). This coefficient depends on the relationship between the physical length of the coupling region and the beating length:
#
# <img src="k.png" alt="Coupling Coefficient Equation" width="400">
#
# Simulate a directional coupler that implements two deep waveguide cores of thickness 300 nm, 1.2 microns width and with a gap of 600 nm between them.
# - Plot the transfer function: K vs L/Lpi
# - Comment the results: distance needed for a complete energy transfer between waveguides, distance needed for splitting power in half..

# %%
# Ejercicio 2
import math
lambda_c = 1.55
dcoupler_cs2 = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.2, 1.2), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness=300 * nm, # Waveguide height 
    gap=600 * nm,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20 # Parameters of the grid
)
dcoupler_neff2 = dcoupler_cs2.n_eff
print(dcoupler_neff2)

L_pi_TE = 0.5*lambda_c/(dcoupler_neff2[0].real-dcoupler_neff2[1].real)
print(L_pi_TE)

L_pi_TM =  0.5*lambda_c/(dcoupler_neff[2].real-dcoupler_neff[3].real)
print(L_pi_TM)
L_TE =np.arange(0,(2*L_pi_TE),5)
L_TM =np.arange(0,(2*L_pi_TE),5)
k_TE=np.sin((1/2)*math.pi*(L_TE/L_pi_TE))**2
k_TM = np.sin((1/2)*math.pi*(L_TE/L_pi_TM))**2

plt.figure(figsize=(10, 5))
plt.plot(L_TE, k_TE, label='Modo TE', color='blue', linewidth=2)

# Estética de la gráfica
plt.title('Potencia Acoplada (K) vs Longitud (L)')
plt.xlabel('Longitud (L)')
plt.ylabel('Coeficiente de acoplo TE (K)')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.ylim(-0.05, 1.05) # Para ver bien los límites 0 y 1
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(L_TM, k_TM, label='Modo TM', color='red', linewidth=2)


# Estética de la gráfica
plt.title('Potencia Acoplada (K) vs Longitud (L)')
plt.xlabel('Longitud (L)')
plt.ylabel('Coeficiente de acoplo TM (K)')
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.ylim(-0.05, 1.05) # Para ver bien los límites 0 y 1
plt.show()
# Out:
# 2026-04-29 17:42:32.630 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbc1bb971a882eda.npz.
# [1.60942484+1.02849974e-04j 1.60116589+9.83178135e-05j
#  1.53540293+1.77367472e-04j 1.52057329+1.77190584e-04j]
# 93.83767536699743
# 52.260223677440635

# %% [markdown]
# Esta constante, te dice cuanto de acoplado, es decir, el porcentaje de la potencia que se va a transmitir a la otra guía en función de la longitud del acoplo que se tenga. Para que haya un acoplo del 100 % en el modo TE la Lpi te tiene que ser la calculada anteriormente. Con el modo TM sucede lo mismo, Podemos ver como los picos donde se transfiere un modo no coinciden con los del otro modo. Con estas gráficas también podemos que longitud tiene que tener el acoplador para dar un porcentaje de la señal. Por ejemplo: Si solo queremos que se pase un 20 % para el modo TE podemos ver como necesitaríamos una Longitud de Lpi de 27 o 28 um.

# %% [markdown]
# ## LO.3. 2x2 Directional Coupler
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 (50/50) directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for Directional Couplers
# Define your geometrical parameters here
wg_gap = 0.6 # Student. Gap between waveguides
wg_width = 1.2 # Student. Core waveguides width

d = wg_width + wg_gap
wg_N = 2

m = DC_EME() # Here you instantiate a Directional Coupler to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_num_modes = 12 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 
m.DC_wg_gap = wg_gap # Gap between waveguides
m.DC_wg_width = wg_width # Width of the waveguides core
m.DC_N_waveguides = wg_N

# 1) Compute de DC modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  94.02742605180929  µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change any geometrical parameter
# (waveguide widths or gap) you can skip last cell. 
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure DC
# DC I/O number
m.n_IN = 2
m.n_OUT = 2

m.L_MMI = 0.5*L_pi # Since we use the same library for propagation simulations of MMI and DC 
                    # some variables might be identified as "MMI". Sorry about that (: 
                    # Might change in the future 

# 4) Run propagation - get power transfer and plot propagation
m.propagation()
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/940 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 47.0137
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9688
# Total OUT power: 0.9583
# Excess loss [dB] =  0.1851
# ------------------------
# Power over OUTs:  ['0.4791', '0.4791']
# Ratio over OUTs ['0.5000', '0.5000']

# %% [markdown]
# Now sweep gaps between 0.2 and 1.2 µm in steps of 0.2 µm

# %%
wg_width = 1.2
gaps = np.arange(0.2, 1.4, 0.2)  
resultados_L_pi = []

for wg_gap in gaps:
    m = DC_EME()
    m.MMI_num_modes = 12 
    m.DC_wg_gap = wg_gap
    m.DC_wg_width = wg_width
    m.DC_N_waveguides = 2

    m.find_all_modes()

    # 3) Obtener L_pi y guardarlo
    L_pi = m.get_L_pi()
    resultados_L_pi.append(L_pi)
    
    print(f"Gap: {wg_gap:.1f} µm -> L_pi: {L_pi:.2f} µm")

    # 4) Opcional: Si quieres ver la propagación de cada uno para L_pi/2
    m.n_IN = 2
    m.n_OUT = 2
    m.L_MMI = 0.5 * L_pi
    m.propagation() # Descomenta esta línea si quieres ver los gráficos uno por uno
# Out:
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 0.2 µm -> L_pi: 25.81 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/258 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 12.9071
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.7802
# Total OUT power: 0.7586
# Excess loss [dB] =  1.2000
# ------------------------
# Power over OUTs:  ['0.3792', '0.3794']
# Ratio over OUTs ['0.4999', '0.5001']
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 0.4 µm -> L_pi: 50.11 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/501 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 25.0550
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.8983
# Total OUT power: 0.8863
# Excess loss [dB] =  0.5243
# ------------------------
# Power over OUTs:  ['0.4433', '0.4430']
# Ratio over OUTs ['0.5001', '0.4999']
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 0.6 µm -> L_pi: 94.03 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/940 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 47.0135
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9687
# Total OUT power: 0.9582
# Excess loss [dB] =  0.1855
# ------------------------
# Power over OUTs:  ['0.4791', '0.4791']
# Ratio over OUTs ['0.5000', '0.5000']
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 0.8 µm -> L_pi: 173.96 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/1740 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 86.9819
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9882
# Total OUT power: 0.9778
# Excess loss [dB] =  0.0976
# ------------------------
# Power over OUTs:  ['0.4888', '0.4890']
# Ratio over OUTs ['0.4999', '0.5001']
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 1.0 µm -> L_pi: 318.88 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/3189 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 159.4421
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9663
# Total OUT power: 0.9560
# Excess loss [dB] =  0.1955
# ------------------------
# Power over OUTs:  ['0.4778', '0.4782']
# Ratio over OUTs ['0.4998', '0.5002']
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# Gap: 1.2 µm -> L_pi: 580.43 µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/5804 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 290.2147
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.8916
# Total OUT power: 0.8818
# Excess loss [dB] =  0.5464
# ------------------------
# Power over OUTs:  ['0.4407', '0.4410']
# Ratio over OUTs ['0.4998', '0.5002']

# %% [markdown]
# ## LO.4. Parallel uncoupled waveguides
#
# Parallel waveguides always exhibit some evanescent coupling. In this exercise, the goal is to control coupling so that adjacent waveguides remain effectively uncoupled. Define an uncoupled pair as one with coupling coefficient K < 0.01. Assume a parallel interaction length of L = 10 mm (typical chip length). For both shallow-etched and deep-etched waveguides, compute the minimum waveguide gap that satisfies this condition for the **TE0** mode, using w = 1.0 um and lambda = 1.55 um.

# %%
# HINT. Calculate manually the L_pi you may need to achieve K=0.01
# Then you can sweep the gap and calculate the L_pi until reaching 
# the desired value. 
# Parámetros del ejercicio LO4
L_chip_um = 10  # 10 mm convertidos a micras
K_limit = 0.01
lambda_c = 1.55
# Umbral crítico en micras
L_pi_target = (np.pi * L_chip_um) / (2 * np.arcsin(np.sqrt(K_limit)))
print(L_pi_target)
gaps = np.arange(2.0, 4.2, 0.1)
l_pi_results = []
# 3. Bucle de simulación
for g in gaps:
    dcoupler_calculado = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.0, 1.0), # Waveguide width
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness= 300*nm, # Waveguide height 
    gap=g,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    )
    dcoupler_neff2 = dcoupler_calculado.n_eff
    L_pi_res = 0.5*lambda_c/abs(dcoupler_neff2[0].real-dcoupler_neff2[1].real)
    l_pi_results.append(int(L_pi_res)/1000)
indice_cercano = np.abs(l_pi_results - L_pi_target).argmin()
gap_optimo = gaps[indice_cercano]
print(l_pi_results)
print(gap_optimo)
print(l_pi_results[indice_cercano])
# 1. Configuramos el tamaño de la figura
plt.figure(figsize=(10, 6))
plt.plot(gaps, l_pi_results, 'bo-', label='L_pi calculada')
plt.title('Barrido de Gap vs Longitud de Acoplamiento ($L_{\pi}$)', fontsize=14)
plt.xlabel('Gap [$\mu m$]', fontsize=12)
plt.ylabel('$L_{\pi}$ [mm]', fontsize=12)
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend()
plt.show()
# Out:
# 156.81708768975523
# 2026-04-29 17:44:12.565 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de3e6ab596cc7c98.npz.
# 2026-04-29 17:44:12.579 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_94d6a82a72a7e737.npz.
# 2026-04-29 17:44:12.581 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_957f1bc4018bf465.npz.
# 2026-04-29 17:44:12.583 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c0b9dcd1db3cffc2.npz.
# 2026-04-29 17:44:12.585 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_aefd241a6242cacd.npz.
# 2026-04-29 17:44:12.587 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_85424e8b1ed643fd.npz.
# 2026-04-29 17:44:12.589 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_360ccc141acfbd30.npz.
# 2026-04-29 17:44:12.591 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2513eb359757876d.npz.
# 2026-04-29 17:44:12.593 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f49c03fcb07cff2.npz.
# 2026-04-29 17:44:12.595 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cdd811462eac5adf.npz.
# 2026-04-29 17:44:12.597 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d3ad085bd24d66be.npz.
# 2026-04-29 17:44:12.599 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_33ac038a2ed63ba7.npz.
# 2026-04-29 17:44:12.601 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e8a62f3681e571b7.npz.
# 2026-04-29 17:44:12.603 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_04ce492eb965b3e2.npz.
# 2026-04-29 17:44:12.604 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b6fb27f0694fb628.npz.
# 2026-04-29 17:44:12.606 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5f3662f5be7cbf49.npz.
# 2026-04-29 17:44:12.608 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0703101aab9d8111.npz.
# 2026-04-29 17:44:12.609 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4f0de85b4053b109.npz.
# 2026-04-29 17:44:12.611 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d47ee5ba087120c7.npz.
# 2026-04-29 17:44:12.612 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9051f326a7a28ac7.npz.
# 2026-04-29 17:44:12.614 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4489ddf5264a3ac0.npz.
# 2026-04-29 17:44:12.616 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3928f8f2f75b1ca4.npz.
# [2.936, 3.76, 1.023, 6.609, 8.434, 1.05, 1.047, 18.865, 25.32, 32.005, 1.045, 1.054, 68.66, 1.054, 108.667, 156.381, 190.751, 198.89, 1.045, 1.055, 217.526, 1.055]
# 3.5000000000000013
# 156.381
# <>:41: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\m'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:41: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\m'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1022/4207851786.py:41: SyntaxWarning: invalid escape sequence '\p'
#   plt.title('Barrido de Gap vs Longitud de Acoplamiento ($L_{\pi}$)', fontsize=14)
# /tmp/ipykernel_1022/4207851786.py:42: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Gap [$\mu m$]', fontsize=12)
# /tmp/ipykernel_1022/4207851786.py:43: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$L_{\pi}$ [mm]', fontsize=12)

# %%
# HINT. Calculate manually the L_pi you may need to achieve K=0.01
# Then you can sweep the gap and calculate the L_pi until reaching 
# the desired value. 
# Parámetros del ejercicio LO4
L_chip_um = 10  # 10 mm convertidos a micras
K_limit = 0.01
lambda_c = 1.55
# Umbral crítico en micras
L_pi_target = (np.pi * L_chip_um) / (2 * np.arcsin(np.sqrt(K_limit)))
print(L_pi_target)
gaps = np.arange(4.5, 5.5, 0.05)
l_pi_results = []
# 3. Bucle de simulación
for g in gaps:
    dcoupler_calculado = gt.modes.WaveguideCoupler(
    # Geometrical Parameters
    core_width=(1.0, 1.0), # Waveguide width
    slab_thickness=150 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguide.
    core_thickness= 300*nm, # Waveguide height 
    gap=g,
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=4, # Number of modes to find
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
    )
    dcoupler_neff2 = dcoupler_calculado.n_eff
    L_pi_res = 0.5*lambda_c/abs(dcoupler_neff2[0].real-dcoupler_neff2[1].real)
    l_pi_results.append(int(L_pi_res)/1000)
indice_cercano = np.abs(l_pi_results - L_pi_target).argmin()
gap_optimo = gaps[indice_cercano]
print(l_pi_results)
print(gap_optimo)
print(l_pi_results[indice_cercano])
# 1. Configuramos el tamaño de la figura
plt.figure(figsize=(10, 6))
plt.plot(gaps, l_pi_results, 'bo-', label='L_pi calculada')
plt.title('Barrido de Gap vs Longitud de Acoplamiento ($L_{\pi}$)', fontsize=14)
plt.xlabel('Gap [$\mu m$]', fontsize=12)
plt.ylabel('$L_{\pi}$ [mm]', fontsize=12)
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend()
plt.show()
# Out:
# 156.81708768975523
# 2026-04-29 17:44:12.743 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_166db9ce5db5a820.npz.
# 2026-04-29 17:44:12.747 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c73c1fb570929f6f.npz.
# 2026-04-29 17:44:12.749 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a69c5ccbe1650eae.npz.
# 2026-04-29 17:44:12.751 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f832107e310997b6.npz.
# 2026-04-29 17:44:12.753 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_3acd90381659a587.npz.
# 2026-04-29 17:44:12.755 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_14a224d5a722b149.npz.
# 2026-04-29 17:44:12.756 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_049639a5f0158918.npz.
# 2026-04-29 17:44:12.759 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_92c2c9dd45c4a6ce.npz.
# 2026-04-29 17:44:12.760 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6c66e346d3c25fd5.npz.
# 2026-04-29 17:44:12.763 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_26b6774832ad29b7.npz.
# 2026-04-29 17:44:12.764 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6c3788927a667d9e.npz.
# <>:41: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\m'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# <>:41: SyntaxWarning: invalid escape sequence '\p'
# <>:42: SyntaxWarning: invalid escape sequence '\m'
# <>:43: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1022/3405033447.py:41: SyntaxWarning: invalid escape sequence '\p'
#   plt.title('Barrido de Gap vs Longitud de Acoplamiento ($L_{\pi}$)', fontsize=14)
# /tmp/ipykernel_1022/3405033447.py:42: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Gap [$\mu m$]', fontsize=12)
# /tmp/ipykernel_1022/3405033447.py:43: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$L_{\pi}$ [mm]', fontsize=12)
# 2026-04-29 17:44:12.766 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_872599b9431ea787.npz.
# 2026-04-29 17:44:12.767 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa1e4c812dfad9bb.npz.
# 2026-04-29 17:44:12.769 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_71b99714d69ebcfd.npz.
# 2026-04-29 17:44:12.771 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8dd836f37f179a75.npz.
# 2026-04-29 17:44:12.773 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a47751c6d328e6e2.npz.
# 2026-04-29 17:44:12.776 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d247d426b45c7db7.npz.
# 2026-04-29 17:44:12.778 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_736a771fdf697820.npz.
# 2026-04-29 17:44:12.779 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_1670cdd015d63a73.npz.
# 2026-04-29 17:44:12.781 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_be2366015864124c.npz.
# [3.356, 75.438, 83.127, 91.096, 3.358, 110.518, 120.936, 132.847, 3.357, 160.232, 175.473, 192.652, 3.353, 3.338, 253.647, 281.64, 3.36, 330.803, 360.206, 416.646]
# 4.949999999999998
# 160.232

# %% [markdown]
# ## LO.5. Multimode Interference (MMI) Coupler cross-section
#
# ### LO.5.1. Cross-Section definition and simulation
#
# In GDSFactory - Tidy3d modesolver, we can simulate the Cross-Section of a multimode interference coupler using the previously studied : [gt.modes.Waveguide()](https://gdsfactory.github.io/gplugins/_autosummary/gplugins.tidy3d.modes.Waveguide.html) function. The parameters will correspond to the dimensions of the MMI body section.

# %%
mmi_body_w = 12  
lambda_c = 1550*nm

mmi_body_waveguide = gt.modes.Waveguide(
    # Geometrical Parameters
    core_width=mmi_body_w, # MMI Body width
    core_thickness=300 * nm, # MMI Body height 
    slab_thickness=0 * nm, # For shallow waveguides - Set to 0 if its a deep-etched waveguides.
    # Materials
    core_material='sin', #  Material of the waveguide
    clad_material='sio2', # Surrounding material
    # Modesolver Parameters
    wavelength=lambda_c, # Wavelength to simulate
    num_modes=20, # Targeted number of modes to find - Higher than before! It's a multimode section
    max_grid_scaling=1.5, # Parameters of the grid
    grid_resolution=20, # Parameters of the grid
    cache_path='.cache/', # Important! In order to save simulation time, set your cache Path!
    precision='double',
)

mmi_body_waveguide.n_eff
# Out:
# 2026-04-29 17:44:12.877 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6c30818797bb0c38.npz.
# array([1.6786595 +7.78934672e-05j, 1.67512732+7.81571827e-05j,
#        1.66922847+7.86028340e-05j, 1.66094525+7.92401466e-05j,
#        1.65025312+8.00839409e-05j, 1.63712124+8.11557006e-05j,
#        1.6215135 +8.24863265e-05j, 1.60339058+8.41212350e-05j,
#        1.58271457+8.61311110e-05j, 1.5774205 +1.66068730e-04j,
#        1.57388942+1.66498915e-04j, 1.56799588+1.67223410e-04j,
#        1.55972723+1.68258132e-04j, 1.5594584 +8.86366882e-05j,
#        1.54906903+1.69617736e-04j, 1.53601168+1.71243999e-04j,
#        1.53362692+9.19569893e-05j, 1.52054265+1.73463904e-04j,
#        1.5053405 +9.64080926e-05j, 1.50269423+1.76086361e-04j])

# %%
mmi_body_waveguide.fraction_te
# Out:
# array([9.99991904e-01, 9.99967183e-01, 9.99924497e-01, 9.99861445e-01,
#        9.99774272e-01, 9.99657368e-01, 9.99502382e-01, 9.99296461e-01,
#        9.99013009e-01, 2.38565216e-04, 9.55099424e-04, 2.13831793e-03,
#        3.73633926e-03, 9.98594348e-01, 5.78997522e-03, 9.32192912e-03,
#        9.96954269e-01, 1.09103635e-02, 9.97247761e-01, 1.38536938e-02])

# %%
mmi_body_waveguide.plot_field(mode_index=0 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)
) #

# %%
mmi_body_waveguide.plot_field(mode_index=1 , # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
mmi_body_waveguide.plot_field(mode_index=7, # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %%
mmi_body_waveguide.plot_field(mode_index=13, # Mode to be plotted
                          field_name='Ex', # Field to be plotted
                          value='real', # Real - abs - imag
                          cmap='coolwarm', # Suggestions: Change the plot color
                          xlim=(-7, 7), # Set the x and y limits
                          ylim=(-0.7, 1)) #

# %% [markdown]
# #### LO.5.2 Length calculation (𝐿𝜋)
#
# With this information, we could calculate our first guess for the 𝐿𝜋 length of the MMI coupler:

# %%
d_n_eff = mmi_body_waveguide.n_eff[0].real -  mmi_body_waveguide.n_eff[1].real

L_pi = 0.5*lambda_c/(d_n_eff)

print (L_pi)
# Out:
# 219.41119794412975

# %% [markdown]
# ## LO.6. 2x2 Multimode Interference Coupler
#
# ### LO.6.1 Propagation Simulation

# %% [markdown]
# For the multimode interference (MMI) couplers we must rely on the design tables shown on the theoretical session:
#
# <img src="mmi.png" alt="Design tables for MMI couplers" width="600">
#
# Here, you will use some functions provided by us (check **0. Imports** for more details) to simulate the propagation in a 2x2 directional coupler. Please read all the comments in the following code carefully and **make changes only to the lines marked with the #Student tag**

# %%
# Simulation flow for MMI Couplers
# Define your geometrical parameters here
mmi_Width = 6.6 # Student. Body width

m = MMI_EME() # Here you instantiate a MMI to be simulated with the Eigen-mode expansion (EME) algorithm.
m.MMI_width = mmi_Width
m.MMI_num_modes = 30 # Number of modes to be calculated. Here, the higher, the better since we are going to calculate
                    # the propagation based on the mode decomposition. 

# 1) Compute de MMI body modes - Only execute whenever a geometrical parameter is changed. Takes time to find the modes. 
m.find_all_modes()

# 2) Get the L_pi 
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607256141  µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN =  2 # STUDENT
m.n_OUT = 2 # STUDENT

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/690 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.0000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9604
# Total OUT power: 0.9075
# Excess loss [dB] =  0.4217
# ------------------------
# Power over OUTs:  ['0.4675', '0.4399']
# Ratio over OUTs ['0.5152', '0.4848']

# %% [markdown]
# ### LO.6.2. 2x2 Multimode Interference Coupler - Optimization

# %%
dy = 0.09
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.dL_MMI = -0.8  # STUDENT
    
# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/674 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment -0.8000
# IO wg width 1.0000
# IO wg width increment 0.0000
# ------------------------
# Total power IN coupled 0.9535
# Total OUT power: 0.9020
# Excess loss [dB] =  0.4480
# ------------------------
# Power over OUTs:  ['0.4502', '0.4518']
# Ratio over OUTs ['0.4991', '0.5009']

# %% [markdown]
# ### LO.6.3 2x2 Multimode Interference Coupler – Optimization (II)

# %%
# Design flow for MMI

m = MMI_EME()
m.MMI_width = 6.6   # MMI width
m.wg_width_dw = 1.2 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  69.03598607257643  µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN = 2 # STUDENT
m.n_OUT = 2 # STUDENT

dy = 0.15
# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy]) # STUDENT
m.OUT_WVG_positions = mmi_Width*np.array([-1/6,1/6]) + np.array([-dy,dy])  # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (1/2)*L_pi  # STUDENT
m.dL_MMI = 0.1  # STUDENT

# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/692 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 34.5180
# MMI length increment 0.1000
# IO wg width 1.0000
# IO wg width increment 1.2000
# ------------------------
# Total power IN coupled 0.9992
# Total OUT power: 0.9817
# Excess loss [dB] =  0.0800
# ------------------------
# Power over OUTs:  ['0.4908', '0.4910']
# Ratio over OUTs ['0.4999', '0.5001']

# %% [markdown]
# ## LO.7. 1x4 Multimode Interference Coupler
#
# Repeat the design procedure explained for the 2x2 Coupler to design a 1x4 MMI Coupler. Consider:
# - Select a suitable MMI body width, taking into account that you now must allocate 4 waveguides at the output.
# - Minimize the losses and output imbalance for the MMI coupler.

# %%
# Design flow for MMI

m = MMI_EME()
m.MMI_width = 6.2   # MMI width
m.wg_width_dw = 0.2 # STUDENT

# 1) Compute de MMI modes
m.find_all_modes()

# 2) Get the L_pi
L_pi = m.get_L_pi()
print("L_pi = ", L_pi, " µm")
# Out:
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)
# L_pi =  61.27610500997027  µm
# /home/raul/cifoin-lab2/.venv/lib/python3.12/site-packages/skfem/assembly/form/linear_form.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   data[ixs] = self._kernel(vbasis.basis[i], w, dx)

# %%
# IMPORTANT!!! 
# # If you DON'T change neither the MMI width 
# nor input/output waveguide widths
# YOU CAN RUN the lines below as many times as you wish
# (SAVES TIME)

# 3) Configure MMI
# # MMI I/O number (check class slides for type of MMI)
m.n_IN =  1# STUDENT
m.n_OUT = 4 # STUDENT

# MMI I/O waveguide positions (check class slides for type of MMI)
m.IN_WVG_positions = mmi_Width*np.array([0]) # STUDENT
m.OUT_WVG_positions =mmi_Width*np.array([-3/8, -1/8, 1/8, 3/8]) # STUDENT

# MMI length (check class slides for type of MMI)
m.L_MMI = (3/16) * L_pi # STUDENT
m.dL_MMI = 0.8 # STUDENT
# Run propagation
m.propagation()
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/246 [00:00<?, ?it/s]
# ------- Pameters -------
# MMI length 11.4893
# MMI length increment 0.8000
# IO wg width 1.0000
# IO wg width increment 0.2000
# ------------------------
# Total power IN coupled 0.9839
# Total OUT power: 0.9838
# Excess loss [dB] =  0.0711
# ------------------------
# Power over OUTs:  ['0.2455', '0.2465', '0.2463', '0.2455']
# Ratio over OUTs ['0.2495', '0.2506', '0.2504', '0.2495']

# %% [markdown]
# ## Extra - Exercises

# %% [markdown]
# ### E1. Directional coupler gap dependence

# %%
# --- CONFIGURACIÓN INICIAL ---
nm = 1e-3
lambda_c = 1.55  # Longitud de onda en micras
gap_to_simulate = np.arange(0.2, 2.6, 0.2)

# Listas para almacenar los resultados
gaps_validos_te = []
l_pi_te_list = []
gaps_validos_tm = []
l_pi_tm_list = []

print(f"{'Gap (um)':<10} | {'L_pi_TE (um)':<15} | {'L_pi_TM (um)':<15}")
print("-" * 45)

# --- BUCLE DE SIMULACIÓN ---
for g in gap_to_simulate:
    # Definimos el acoplador para el gap actual 'g'
    dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=lambda_c,
        core_width=(1.0, 1.0),
        gap=g,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=4, # Aumentamos a 4 para asegurar capturar pares e impares de ambos
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )
    
    neffs = dcoupler_cs.n_eff
    te_fraction = dcoupler_cs.fraction_te
    
    # --- PROCESAMIENTO TE ---
    te_indices = np.where(te_fraction > 0.5)[0]
    l_pi_te = None
    if len(te_indices) >= 2:
        n_even_te = neffs[te_indices[0]].real
        n_odd_te = neffs[te_indices[1]].real
        l_pi_te = abs(0.5 * lambda_c / (n_even_te - n_odd_te))
        l_pi_te_list.append(l_pi_te)
        gaps_validos_te.append(g)

    # --- PROCESAMIENTO TM ---
    # Los modos TM tienen una fracción TE baja (generalmente < 0.5)
    tm_indices = np.where(te_fraction < 0.5)[0]
    l_pi_tm = None
    if len(tm_indices) >= 2:
        n_even_tm = neffs[tm_indices[0]].real
        n_odd_tm = neffs[tm_indices[1]].real
        l_pi_tm = abs(0.5 * lambda_c / (n_even_tm - n_odd_tm))
        l_pi_tm_list.append(l_pi_tm)
        gaps_validos_tm.append(g)

    # Imprimir resultados en tabla
    te_str = f"{l_pi_te:.2f}" if l_pi_te else "Error"
    tm_str = f"{l_pi_tm:.2f}" if l_pi_tm else "Error"
    print(f"{g:<10.2f} | {te_str:<15} | {tm_str:<15}")

# --- GENERACIÓN DE LA GRÁFICA ---
plt.figure(figsize=(10, 6))

# Gráfica TE
plt.plot(gaps_validos_te, l_pi_te_list, 'bo-', label='$L_\pi$ TE', linewidth=2)

# Gráfica TM
plt.plot(gaps_validos_tm, l_pi_tm_list, 'ro--', label='$L_\pi$ TM', linewidth=2)

# Configuración de etiquetas y títulos
plt.title(r'Longitud de Acoplamiento $L_\pi$ vs Gap (TE vs TM)', fontsize=14)
plt.xlabel('Gap ($\mu$m)', fontsize=12)
plt.ylabel('$L_\pi$ ($\mu$m)', fontsize=12)

# Escala logarítmica (Recomendada ya que Lpi crece muy rápido con el Gap)

plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Gap (um)   | L_pi_TE (um)    | L_pi_TM (um)
# ---------------------------------------------
# 2026-04-30 16:15:11.013 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_19fc40f5ad5a09a8.npz.
# 0.20       | 17.69           | 16.72
# 2026-04-30 16:15:11.015 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_266d67620f0948f9.npz.
# 0.40       | 32.69           | 25.45
# 2026-04-30 16:15:11.018 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fa4c4babd472f540.npz.
# 0.60       | 58.77           | 38.43
# 2026-04-30 16:15:11.021 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f8167db7728a9ebb.npz.
# 0.80       | 103.11          | 56.51
# 2026-04-30 16:15:11.024 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b0f701e58db4a1bf.npz.
# 1.00       | 183.51          | 85.35
# 2026-04-30 16:15:11.026 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_de78bc7bac7ad149.npz.
# 1.20       | 320.54          | 125.67
# 2026-04-30 16:15:11.028 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69d8430ee5b848c9.npz.
# 1.40       | 556.78          | 183.82
# 2026-04-30 16:15:11.030 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ce577367a47a40cf.npz.
# 1.60       | 963.20          | 267.43
# 2026-04-30 16:15:11.032 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_51919864b2bb47b4.npz.
# 1.80       | 878.42          | 344.28
# 2026-04-30 16:15:11.034 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e0bd02e52bb6fea.npz.
# 2.00       | 2855.03         | 558.73
# 2026-04-30 16:15:11.037 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_cbd4017b74156e86.npz.
# 2.20       | 4898.71         | 803.36
# 2026-04-30 16:15:11.039 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_186b33d829047bed.npz.
# 2.40       | 8380.03         | 1151.93
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:69: SyntaxWarning: invalid escape sequence '\p'
# <>:73: SyntaxWarning: invalid escape sequence '\m'
# <>:74: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:69: SyntaxWarning: invalid escape sequence '\p'
# <>:73: SyntaxWarning: invalid escape sequence '\m'
# <>:74: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1024/1669680733.py:66: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(gaps_validos_te, l_pi_te_list, 'bo-', label='$L_\pi$ TE', linewidth=2)
# /tmp/ipykernel_1024/1669680733.py:69: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(gaps_validos_tm, l_pi_tm_list, 'ro--', label='$L_\pi$ TM', linewidth=2)
# /tmp/ipykernel_1024/1669680733.py:73: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Gap ($\mu$m)', fontsize=12)
# /tmp/ipykernel_1024/1669680733.py:74: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$L_\pi$ ($\mu$m)', fontsize=12)

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- CONFIGURACIÓN INICIAL ---
nm = 1e-3
lambda_c = 1.55  # Longitud de onda en micras
gap_to_simulate = np.arange(0.2, 2.6, 0.2)

# Listas para almacenar los resultados
gaps_validos_te = []
l_pi_te_list = []
gaps_validos_tm = []
l_pi_tm_list = []

print(f"{'Gap (um)':<10} | {'L_pi_TE (um)':<15} | {'L_pi_TM (um)':<15}")
print("-" * 45)

# --- BUCLE DE SIMULACIÓN ---
for g in gap_to_simulate:
    # Definimos el acoplador para el gap actual 'g'
    dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=lambda_c,
        core_width=(1.0, 1.0),
        gap=g,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=4, # Aumentamos a 4 para asegurar capturar pares e impares de ambos
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )
    
    neffs = dcoupler_cs.n_eff
    te_fraction = dcoupler_cs.fraction_te
    
    # --- PROCESAMIENTO TE ---
    te_indices = np.where(te_fraction > 0.5)[0]
    l_pi_te = None
    if len(te_indices) >= 2:
        n_even_te = neffs[te_indices[0]].real
        n_odd_te = neffs[te_indices[1]].real
        l_pi_te = abs(0.5 * lambda_c / (n_even_te - n_odd_te))
        l_pi_te_list.append(l_pi_te)
        gaps_validos_te.append(g)

    # --- PROCESAMIENTO TM ---
    # Los modos TM tienen una fracción TE baja (generalmente < 0.5)
    tm_indices = np.where(te_fraction < 0.5)[0]
    l_pi_tm = None
    if len(tm_indices) >= 2:
        n_even_tm = neffs[tm_indices[0]].real
        n_odd_tm = neffs[tm_indices[1]].real
        l_pi_tm = abs(0.5 * lambda_c / (n_even_tm - n_odd_tm))
        l_pi_tm_list.append(l_pi_tm)
        gaps_validos_tm.append(g)

    # Imprimir resultados en tabla
    te_str = f"{l_pi_te:.2f}" if l_pi_te else "Error"
    tm_str = f"{l_pi_tm:.2f}" if l_pi_tm else "Error"
    print(f"{g:<10.2f} | {te_str:<15} | {tm_str:<15}")

# --- GENERACIÓN DE LA GRÁFICA ---
plt.figure(figsize=(10, 6))

# Gráfica TE
plt.plot(gaps_validos_te, l_pi_te_list, 'bo-', label='$L_\pi$ TE', linewidth=2)

# Gráfica TM
plt.plot(gaps_validos_tm, l_pi_tm_list, 'ro--', label='$L_\pi$ TM', linewidth=2)

# Configuración de etiquetas y títulos
plt.title(r'Longitud de Acoplamiento $L_\pi$ vs Gap (TE vs TM)', fontsize=14)
plt.xlabel('Gap ($\mu$m)', fontsize=12)
plt.ylabel('$L_\pi$ ($\mu$m)', fontsize=12)
plt.grid(True, which="both", ls="-", alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Gap (um)   | L_pi_TE (um)    | L_pi_TM (um)
# ---------------------------------------------
# 2026-04-30 16:15:26.890 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8c8eb63846dcafc2.npz.
# 0.20       | 17.71           | Error
# 2026-04-30 16:15:26.893 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9f55a49562c957ac.npz.
# 0.40       | 26.45           | Error
# 2026-04-30 16:15:26.895 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_0aace39711989615.npz.
# 0.60       | 39.25           | Error
# 2026-04-30 16:15:26.898 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_469dd463acb1cce2.npz.
# 0.80       | 57.95           | Error
# 2026-04-30 16:15:26.900 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_12053cc304837a1c.npz.
# 1.00       | 85.76           | Error
# 2026-04-30 16:15:26.902 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_64ce3e0adbff4874.npz.
# 1.20       | 126.36          | Error
# 2026-04-30 16:15:26.904 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9664102640d36134.npz.
# 1.40       | 185.87          | Error
# 2026-04-30 16:15:26.906 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a7be85a5f0c2c3ff.npz.
# 1.60       | 273.08          | Error
# 2026-04-30 16:15:26.908 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_619b4739561083d3.npz.
# 1.80       | 397.70          | Error
# 2026-04-30 16:15:26.910 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9983c5c8ec0df30b.npz.
# 2.00       | 588.23          | 839.94
# 2026-04-30 16:15:26.912 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_295e702940328765.npz.
# 2.20       | 862.79          | 1951.62
# 2026-04-30 16:15:26.914 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2d34b91294a1c485.npz.
# 2.40       | 1265.23         | 296490.76
# <>:69: SyntaxWarning: invalid escape sequence '\p'
# <>:72: SyntaxWarning: invalid escape sequence '\p'
# <>:76: SyntaxWarning: invalid escape sequence '\m'
# <>:77: SyntaxWarning: invalid escape sequence '\p'
# <>:69: SyntaxWarning: invalid escape sequence '\p'
# <>:72: SyntaxWarning: invalid escape sequence '\p'
# <>:76: SyntaxWarning: invalid escape sequence '\m'
# <>:77: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1024/2253959793.py:69: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(gaps_validos_te, l_pi_te_list, 'bo-', label='$L_\pi$ TE', linewidth=2)
# /tmp/ipykernel_1024/2253959793.py:72: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(gaps_validos_tm, l_pi_tm_list, 'ro--', label='$L_\pi$ TM', linewidth=2)
# /tmp/ipykernel_1024/2253959793.py:76: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel('Gap ($\mu$m)', fontsize=12)
# /tmp/ipykernel_1024/2253959793.py:77: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel('$L_\pi$ ($\mu$m)', fontsize=12)

# %% [markdown]
# ### E2. Directional coupler wavelength dependence

# %%
# Definición del rango de longitudes de onda (ajustado el paso a 0.05 para ver la curva)
wavelength_sweep = np.arange(1.5, 1.77, 0.01) 
l_pi_te_list = []
valid_wavelengths = []
l_pi_tm_list = []
valid_wavelengths_tm = []

for wl in wavelength_sweep:
    # Ejecutamos el coupler para cada longitud de onda individual
    deep_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=wl, 
        core_width=(1.0, 1.0),
        gap=600 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=4,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )
    
    # Obtenemos índices y fracciones TE
    neffs = deep_dcoupler_cs.n_eff
    te_fraction = deep_dcoupler_cs.fraction_te
    
    # Buscamos los 2 primeros modos TE
    te_indices = np.where(te_fraction > 0.5)[0]
    
    if len(te_indices) >= 2:
        n_even = neffs[te_indices[0]].real
        n_odd = neffs[te_indices[1]].real
        
        # Cálculo de L_pi: 0.5 * lambda / (n_even - n_odd)
        l_pi = abs(0.5 * wl / (n_even - n_odd))
        l_pi_te_list.append(l_pi)
        valid_wavelengths.append(wl)
    else:
        print(f"Aviso: No se encontraron 2 modos TE para lambda = {wl}")

    tm_indices = np.where(te_fraction < 0.5)[0]
    
    if len(tm_indices) >= 2:
        n_even_tm = neffs[tm_indices[0]].real
        n_odd_tm = neffs[tm_indices[1]].real
        
        # Cálculo de L_pi: 0.5 * lambda / (n_even - n_odd)
        l_pi_tm = abs(0.5 * wl / (n_even_tm - n_odd_tm))
        l_pi_tm_list.append(l_pi_tm)
        valid_wavelengths_tm.append(wl)
    else:
        print(f"Aviso: No se encontraron 2 modos TM para lambda = {wl}")

# Convertimos a array para el plot
L_pi_TE = np.array(l_pi_te_list)
wavelength_plot = np.array(valid_wavelengths)
L_pi_TM = np.array(l_pi_tm_list)
wavelength_plot_tm = np.array(valid_wavelengths_tm)

# --- GRÁFICA ---
plt.figure(figsize=(10, 5))
plt.scatter(wavelength_plot, L_pi_TE, edgecolors='k', facecolors='none', label='__nolegend__')
plt.plot(wavelength_plot, L_pi_TE, label='Deep', marker='o')
plt.plot(wavelength_plot_tm, L_pi_TM, 'ro--', label='$L_\pi$ TM', linewidth=2)

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi (um)")
plt.title(r"Barrido de $L_\pi$ en función de la Longitud de Onda")
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.show()
# Out:
# 2026-04-30 16:20:42.865 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_fc2c62c75e0d5f6e.npz.
# 2026-04-30 16:20:42.867 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6eef774a0d3d05cd.npz.
# 2026-04-30 16:20:42.871 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7204f407c71c1ae9.npz.
# 2026-04-30 16:20:42.872 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a0ce23b6137b45c7.npz.
# 2026-04-30 16:20:42.875 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_28b1e0ce04fc49df.npz.
# 2026-04-30 16:20:42.878 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b966fe1ac7f3af0a.npz.
# 2026-04-30 16:20:42.880 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_6a889f60cad0254f.npz.
# 2026-04-30 16:20:42.882 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_69332ae76ab54d2a.npz.
# 2026-04-30 16:20:42.884 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_4bcaa6004cef52c0.npz.
# 2026-04-30 16:20:42.886 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_85753f5e2075e804.npz.
# 2026-04-30 16:20:42.889 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_552f5b317d74e723.npz.
# 2026-04-30 16:20:42.891 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_7f6dbe708d81cce8.npz.
# 2026-04-30 16:20:42.893 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_47d9baf8da8037aa.npz.
# 2026-04-30 16:20:42.895 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_5cfd31fa1ff856b2.npz.
# 2026-04-30 16:20:42.897 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9e1f64e3ac6fa25d.npz.
# 2026-04-30 16:20:42.899 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a42508d00a41a022.npz.
# 2026-04-30 16:20:42.901 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_60bff53ded923a1c.npz.
# 2026-04-30 16:20:42.903 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_66d966f66c2c62ce.npz.
# 2026-04-30 16:20:42.905 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_469fb9fef2a1ec5d.npz.
# 2026-04-30 16:20:42.908 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a26ab91d10313942.npz.
# 2026-04-30 16:20:42.910 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e2d37f610d81aedb.npz.
# 2026-04-30 16:20:42.912 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2537696676d4abbd.npz.
# 2026-04-30 16:20:42.915 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_9dd6d59d25475bf8.npz.
# 2026-04-30 16:20:42.917 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_93bbc94d19e0bfad.npz.
# 2026-04-30 16:20:42.920 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d4ec205f5400ad4d.npz.
# 2026-04-30 16:20:42.922 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8e449c80dcae5e3f.npz.
# 2026-04-30 16:20:42.925 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c99dcf77b9f80cf4.npz.
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# <>:66: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1024/2746724518.py:66: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(wavelength_plot_tm, L_pi_TM, 'ro--', label='$L_\pi$ TM', linewidth=2)

# %%
# Definición del rango de longitudes de onda (ajustado el paso a 0.05 para ver la curva)
wavelength_sweep = np.arange(1.5, 1.77, 0.01) 
l_pi_te_list = []
valid_wavelengths = []
l_pi_tm_list = []
valid_wavelengths_tm = []

for wl in wavelength_sweep:
    # Ejecutamos el coupler para cada longitud de onda individual
    deep_dcoupler_cs = gt.modes.WaveguideCoupler(
        wavelength=wl, 
        core_width=(1.0, 1.0),
        gap=600 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        core_thickness=300 * nm,
        num_modes=8,
        cache_path='.cache/',
        precision='double',
        max_grid_scaling=1.5,
        grid_resolution=20
    )
    
    # Obtenemos índices y fracciones TE
    neffs = deep_dcoupler_cs.n_eff
    te_fraction = deep_dcoupler_cs.fraction_te
    # Buscamos los 2 primeros modos TE
    te_indices = np.where(te_fraction > 0.5)[0]
    
    if len(te_indices) >= 2:
        n_even = neffs[te_indices[0]].real
        n_odd = neffs[te_indices[1]].real
        
        # Cálculo de L_pi: 0.5 * lambda / (n_even - n_odd)
        l_pi = abs(0.5 * wl / (n_even - n_odd))
        l_pi_te_list.append(l_pi)
        valid_wavelengths.append(wl)
    else:
        print(f"Aviso: No se encontraron 2 modos TE para lambda = {wl}")

    tm_indices = np.where(te_fraction < 0.5)[0]
    
    if len(tm_indices) >= 2:
        n_even_tm = neffs[tm_indices[0]].real
        n_odd_tm = neffs[tm_indices[1]].real
        
        # Cálculo de L_pi: 0.5 * lambda / (n_even - n_odd)
        l_pi_tm = abs(0.5 * wl / (n_even_tm - n_odd_tm))
        l_pi_tm_list.append(l_pi_tm)
        valid_wavelengths_tm.append(wl)
    else:
        print(f"Aviso: No se encontraron 2 modos TM para lambda = {wl}")

# Convertimos a array para el plot
L_pi_TE = np.array(l_pi_te_list)
wavelength_plot = np.array(valid_wavelengths)
L_pi_TM = np.array(l_pi_tm_list)
wavelength_plot_tm = np.array(valid_wavelengths_tm)

# --- GRÁFICA ---
plt.figure(figsize=(10, 5))
plt.scatter(wavelength_plot, L_pi_TE, edgecolors='k', facecolors='none', label='__nolegend__')
plt.plot(wavelength_plot, L_pi_TE, label='Deep', marker='o')
plt.plot(wavelength_plot_tm, L_pi_TM, 'ro--', label='$L_\pi$ TM', linewidth=2)

plt.xlabel("Wavelength (um)")
plt.ylabel("L_pi (um)")
plt.title(r"Barrido de $L_\pi$ en función de la Longitud de Onda")
plt.grid(True)
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout(rect=[0, 0, 0.85, 1])
plt.show()
# Out:
# 2026-04-30 16:38:22.195 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_96366e64f2261531.npz.
# 2026-04-30 16:38:22.198 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_82dae10517347759.npz.
# 2026-04-30 16:38:22.200 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_825d0a38cb57f00d.npz.
# 2026-04-30 16:38:22.203 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_21db26ab7959afe7.npz.
# 2026-04-30 16:38:22.205 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_8d2597f571f62117.npz.
# 2026-04-30 16:38:22.207 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_35db2e2c835b791a.npz.
# 2026-04-30 16:38:22.209 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_c7c71ebc194077d8.npz.
# 2026-04-30 16:38:22.212 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a313dd43ff6febe0.npz.
# 2026-04-30 16:38:22.214 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ba35c131f4d52dfc.npz.
# 2026-04-30 16:38:22.216 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e1e22c0af9e8ddfd.npz.
# 2026-04-30 16:38:22.218 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b2ba9af71b19b2de.npz.
# 2026-04-30 16:38:22.221 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_b529c38ebd028ac6.npz.
# 2026-04-30 16:38:22.223 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a5fc42570101ac1f.npz.
# 2026-04-30 16:38:22.226 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a45e66319df813e4.npz.
# 2026-04-30 16:38:22.228 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_95a673533a6532b0.npz.
# 2026-04-30 16:38:22.230 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_f797ba6d07472a0e.npz.
# 2026-04-30 16:38:22.233 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_401e8cc41e868e57.npz.
# 2026-04-30 16:38:22.235 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_adc8b55a0127f874.npz.
# 2026-04-30 16:38:22.237 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_bf7dd528cb4cca30.npz.
# 2026-04-30 16:38:22.240 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_20cf5b77dedc6291.npz.
# 2026-04-30 16:38:22.241 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_e18b5c5a4b85bc11.npz.
# 2026-04-30 16:38:22.244 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_d66b1599a4a879f1.npz.
# 2026-04-30 16:38:22.246 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_2d5af287bf79beee.npz.
# 2026-04-30 16:38:22.248 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_89586347df76beac.npz.
# 2026-04-30 16:38:22.250 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_ae3fb822a112931d.npz.
# 2026-04-30 16:38:22.253 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_a56856957819cd57.npz.
# 2026-04-30 16:38:22.255 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/WaveguideCoupler_71fae26572812f2f.npz.
# <>:65: SyntaxWarning: invalid escape sequence '\p'
# <>:65: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1024/1581008398.py:65: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(wavelength_plot_tm, L_pi_TM, 'ro--', label='$L_\pi$ TM', linewidth=2)

# %% [markdown]
# ### E3. MMI coupler wavelength dependence

# %%
# 1. Definición del rango de longitudes de onda
lambda_c_sweep = np.arange(1.5, 1.7, 0.01)

# Listas temporales para recolectar datos
l_pi_te_list = []
wl_te_list = []
l_pi_tm_list = []
wl_tm_list = []

for wl in lambda_c_sweep:
    # Definición del MMI
    mmi_body = gt.modes.Waveguide(
        core_width=6.6, 
        core_thickness=300 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=wl,
        num_modes=40,  # Importante: muchos modos para capturar TM en guías anchas
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )
    
    neffs = mmi_body.n_eff
    te_fracs = mmi_body.fraction_te
    
    # --- PROCESAMIENTO TE ---
    te_idx = np.where(te_fracs > 0.5)[0]
    if len(te_idx) >= 2:
        n0_te = neffs[te_idx[0]].real
        n1_te = neffs[te_idx[1]].real
        l_pi_te_list.append(abs(0.5 * wl / (n0_te - n1_te)))
        wl_te_list.append(wl)

    # --- PROCESAMIENTO TM ---
    tm_idx = np.where(te_fracs < 0.5)[0]
    if len(tm_idx) >= 2:
        n0_tm = neffs[tm_idx[0]].real
        n1_tm = neffs[tm_idx[1]].real
        l_pi_tm_list.append(abs(0.5 * wl / (n0_tm - n1_tm)))
        wl_tm_list.append(wl)
    else:
        print(f"Aviso: No se encontraron suficientes modos TM para {wl} um")

# 2. Creación de ARRAYS INDEPENDIENTES
L_PI_TE = np.array(l_pi_te_list)
WL_TE   = np.array(wl_te_list)

L_PI_TM = np.array(l_pi_tm_list)
WL_TM   = np.array(wl_tm_list)

# --- GRÁFICA ---
plt.figure(figsize=(10, 6))

# Gráfica TE
plt.plot(WL_TE, L_PI_TE, 'o-', color='royalblue', label='$L_\pi$ TE', linewidth=2)

# Gráfica TM
plt.plot(WL_TM, L_PI_TM, 's--', color='crimson', label='$L_\pi$ TM', linewidth=2)

plt.xlabel("Wavelength ($\mu$m)")
plt.ylabel("$L_\pi$ ($\mu$m)")
plt.title("Comparativa de Longitud de Batido en MMI (Arrays Independientes)")
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2026-04-30 16:33:21.342 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9d9373fd4f3bf127.npz.
# 2026-04-30 16:33:21.345 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a98192f9ef3b3bd9.npz.
# 2026-04-30 16:33:21.347 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_439b2374c8b8630f.npz.
# 2026-04-30 16:33:21.349 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c89eb7f41f22bda2.npz.
# 2026-04-30 16:33:21.352 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8220955e619d3f86.npz.
# 2026-04-30 16:33:21.354 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2355c28a3c97899c.npz.
# 2026-04-30 16:33:21.356 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7747a60310628db9.npz.
# 2026-04-30 16:33:21.359 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8615e314ff12ccba.npz.
# 2026-04-30 16:33:21.361 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_91b4a26330c751d9.npz.
# 2026-04-30 16:33:21.363 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_cdac0b7562ec0961.npz.
# 2026-04-30 16:33:21.365 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1dd6bf483ce880c7.npz.
# 2026-04-30 16:33:21.367 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_04025c2af7ff4803.npz.
# 2026-04-30 16:33:21.369 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_22c4c06bfa61abde.npz.
# 2026-04-30 16:33:21.371 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c8d141945fed47e5.npz.
# 2026-04-30 16:33:21.373 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7384a24e691c177f.npz.
# 2026-04-30 16:33:21.375 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_6a7ec7d8aa273698.npz.
# 2026-04-30 16:33:21.377 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e4ed3f2c89987f88.npz.
# 2026-04-30 16:33:21.379 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f42c69274c64b3a8.npz.
# 2026-04-30 16:33:21.381 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2385f0a01d5cc463.npz.
# 2026-04-30 16:33:21.383 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_9302a5281e224375.npz.
# <>:58: SyntaxWarning: invalid escape sequence '\p'
# <>:61: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# <>:58: SyntaxWarning: invalid escape sequence '\p'
# <>:61: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_1024/1279163206.py:58: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(WL_TE, L_PI_TE, 'o-', color='royalblue', label='$L_\pi$ TE', linewidth=2)
# /tmp/ipykernel_1024/1279163206.py:61: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(WL_TM, L_PI_TM, 's--', color='crimson', label='$L_\pi$ TM', linewidth=2)
# /tmp/ipykernel_1024/1279163206.py:63: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength ($\mu$m)")
# /tmp/ipykernel_1024/1279163206.py:64: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$L_\pi$ ($\mu$m)")

# %%
# 1. Definición del rango de longitudes de onda
lambda_c_sweep = np.arange(1.5, 1.7, 0.01)

# Listas temporales para recolectar datos
l_pi_te_list = []
wl_te_list = []
l_pi_tm_list = []
wl_tm_list = []

for wl in lambda_c_sweep:
    # Definición del MMI
    mmi_body = gt.modes.Waveguide(
        core_width=6.6, 
        core_thickness=300 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=wl,
        num_modes=15,  # Importante: muchos modos para capturar TM en guías anchas
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )
    
    neffs = mmi_body.n_eff
    te_fracs = mmi_body.fraction_te
    
    # --- PROCESAMIENTO TE ---
    te_idx = np.where(te_fracs > 0.5)[0]
    if len(te_idx) >= 2:
        n0_te = neffs[te_idx[0]].real
        n1_te = neffs[te_idx[1]].real
        l_pi_te_list.append(abs(0.5 * wl / (n0_te - n1_te)))
        wl_te_list.append(wl)

    # --- PROCESAMIENTO TM ---
    tm_idx = np.where(te_fracs < 0.5)[0]
    if len(tm_idx) >= 2:
        n0_tm = neffs[tm_idx[0]].real
        n1_tm = neffs[tm_idx[1]].real
        l_pi_tm_list.append(abs(0.5 * wl / (n0_tm - n1_tm)))
        wl_tm_list.append(wl)
    else:
        print(f"Aviso: No se encontraron suficientes modos TM para {wl} um")

# 2. Creación de ARRAYS INDEPENDIENTES
L_PI_TE = np.array(l_pi_te_list)
WL_TE   = np.array(wl_te_list)

L_PI_TM = np.array(l_pi_tm_list)
WL_TM   = np.array(wl_tm_list)

# --- GRÁFICA ---
plt.figure(figsize=(10, 6))

# Gráfica TE
plt.plot(WL_TE, L_PI_TE, 'o-', color='royalblue', label='$L_\pi$ TE', linewidth=2)

# Gráfica TM
plt.plot(WL_TM, L_PI_TM, 's--', color='crimson', label='$L_\pi$ TM', linewidth=2)

plt.xlabel("Wavelength ($\mu$m)")
plt.ylabel("$L_\pi$ ($\mu$m)")
plt.title("Comparativa de Longitud de Batido en MMI (Arrays Independientes)")
plt.grid(True, which='both', linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2026-04-30 17:17:42.560 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c26c25376372bde5.npz.
# 2026-04-30 17:17:42.574 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c051a2f7db917722.npz.
# 2026-04-30 17:17:42.577 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_fc4096826c51432d.npz.
# 2026-04-30 17:17:42.579 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ee8712a0bc064dcf.npz.
# 2026-04-30 17:17:42.582 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a0df88c3277ba061.npz.
# 2026-04-30 17:17:42.585 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_869eaa6141b95414.npz.
# 2026-04-30 17:17:42.587 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_cdc4c4c6cae6ff97.npz.
# 2026-04-30 17:17:42.589 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_774fe4b377f9f63a.npz.
# 2026-04-30 17:17:42.592 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4aed67775c957b00.npz.
# 2026-04-30 17:17:42.595 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0ec9c9ca4751a5a3.npz.
# 2026-04-30 17:17:42.597 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d9bef4001f4b417c.npz.
# 2026-04-30 17:17:42.600 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_ecdfb1601b414978.npz.
# 2026-04-30 17:17:42.602 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5183e41cbccdeb14.npz.
# 2026-04-30 17:17:42.603 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d514e2e11ee931b1.npz.
# 2026-04-30 17:17:42.605 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2d6cd45ceb301925.npz.
# 2026-04-30 17:17:42.607 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_e8f25bc3d10c1fd4.npz.
# 2026-04-30 17:17:42.610 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c073119afa2f9737.npz.
# 2026-04-30 17:17:42.612 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_b4f2c9bdee9f6593.npz.
# 2026-04-30 17:17:42.614 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_677f9371e79f7860.npz.
# 2026-04-30 17:17:42.616 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_321b46c553dd9852.npz.
# <>:58: SyntaxWarning: invalid escape sequence '\p'
# <>:61: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# <>:58: SyntaxWarning: invalid escape sequence '\p'
# <>:61: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\m'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_895/1001258571.py:58: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(WL_TE, L_PI_TE, 'o-', color='royalblue', label='$L_\pi$ TE', linewidth=2)
# /tmp/ipykernel_895/1001258571.py:61: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(WL_TM, L_PI_TM, 's--', color='crimson', label='$L_\pi$ TM', linewidth=2)
# /tmp/ipykernel_895/1001258571.py:63: SyntaxWarning: invalid escape sequence '\m'
#   plt.xlabel("Wavelength ($\mu$m)")
# /tmp/ipykernel_895/1001258571.py:64: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$L_\pi$ ($\mu$m)")

# %% [markdown]
# ### E4. MMI coupler body width dependence

# %%
# Definición del rango de anchos de 5 a 10 con saltos de 0.5
width_sweep = np.arange(5, 10.1, 0.5)
lambda_c = 1.55
L_pi_TE = []
L_pi_TM = []
valid_widths_te = []
valid_widths_tm = []

for w in width_sweep:
    # Ejecutamos el solver para cada ancho específico
    mmi_body_waveguide = gt.modes.Waveguide(
        core_width=w,
        core_thickness=300 * nm,
        slab_thickness=0 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=20, # Aumentamos ligeramente el número de modos para asegurar encontrar TM
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )
    
    # Extraemos índices efectivos y fracciones TE
    neffs = mmi_body_waveguide.n_eff
    te_fracs = mmi_body_waveguide.fraction_te
    
    # --- PROCESAMIENTO MODOS TE ---
    te_indices = np.where(te_fracs > 0.5)[0]
    if len(te_indices) >= 2:
        n0_te = neffs[te_indices[0]].real
        n1_te = neffs[te_indices[1]].real
        
        l_pi_te_val = abs(0.5 * lambda_c / (n0_te - n1_te))
        L_pi_TE.append(l_pi_te_val)
        valid_widths_te.append(w)

    # --- PROCESAMIENTO MODOS TM ---
    # Los modos TM tienen una fracción TE baja (te_fracs < 0.5)
    tm_indices = np.where(te_fracs < 0.5)[0]
    if len(tm_indices) >= 2:
        n0_tm = neffs[tm_indices[0]].real
        n1_tm = neffs[tm_indices[1]].real
        
        l_pi_tm_val = abs(0.5 * lambda_c / (n0_tm - n1_tm))
        L_pi_TM.append(l_pi_tm_val)
        valid_widths_tm.append(w)

# --- GENERACIÓN DE LA GRÁFICA ---
plt.figure(figsize=(10, 6))

# Plot TE
plt.plot(valid_widths_te, L_pi_TE, 'r-', label='$L_\pi$ TE')

# Plot TM
plt.plot(valid_widths_tm, L_pi_TM, 'bs--', label='$L_\pi$ TM')

# Ajuste del eje X
plt.xticks(np.arange(5, 10.1, 0.5))

plt.xlabel("MMI Width (μm)")
plt.ylabel("$L_\pi$ (μm)")
plt.title("Longitud de batido $L_\pi$ vs Ancho del MMI (TE vs TM)")
plt.grid(True, which='both', linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# 2026-04-30 17:18:20.683 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_47f426520d618363.npz.
# 2026-04-30 17:18:20.687 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0c9dd7989eb63169.npz.
# 2026-04-30 17:18:20.689 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_1736e1c1aaf31dc6.npz.
# 2026-04-30 17:18:20.691 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_f78fcc329c364ed8.npz.
# 2026-04-30 17:18:20.693 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a1de79a988dd243a.npz.
# 2026-04-30 17:18:20.695 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_d77c5c70cde8e35f.npz.
# 2026-04-30 17:18:20.697 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_88a1ff09686df0a6.npz.
# 2026-04-30 17:18:20.699 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_a540ae376bff1262.npz.
# 2026-04-30 17:18:20.701 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_c13668ee2d0e4ffd.npz.
# 2026-04-30 17:18:20.703 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_7f77dd9441e37122.npz.
# 2026-04-30 17:18:20.706 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_53279b07b6844d37.npz.
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:57: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\p'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:57: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\p'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_895/826626071.py:54: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(valid_widths_te, L_pi_TE, 'r-', label='$L_\pi$ TE')
# /tmp/ipykernel_895/826626071.py:57: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(valid_widths_tm, L_pi_TM, 'bs--', label='$L_\pi$ TM')
# /tmp/ipykernel_895/826626071.py:63: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$L_\pi$ (μm)")
# /tmp/ipykernel_895/826626071.py:64: SyntaxWarning: invalid escape sequence '\p'
#   plt.title("Longitud de batido $L_\pi$ vs Ancho del MMI (TE vs TM)")

# %%
# Definición del rango de anchos de 5 a 10 con saltos de 0.5
width_sweep = np.arange(5, 10.1, 0.5)

L_pi_TE = []
L_pi_TM = []
valid_widths_te = []
valid_widths_tm = []

for w in width_sweep:
    # Ejecutamos el solver para cada ancho específico
    mmi_body_waveguide = gt.modes.Waveguide(
        core_width=w,
        core_thickness=300 * nm,
        slab_thickness=150 * nm,
        core_material='sin',
        clad_material='sio2',
        wavelength=lambda_c,
        num_modes=20, # Aumentamos ligeramente el número de modos para asegurar encontrar TM
        max_grid_scaling=1.5,
        grid_resolution=20,
        cache_path='.cache/',
        precision='double',
    )
    
    # Extraemos índices efectivos y fracciones TE
    neffs = mmi_body_waveguide.n_eff
    te_fracs = mmi_body_waveguide.fraction_te
    
    # --- PROCESAMIENTO MODOS TE ---
    te_indices = np.where(te_fracs > 0.5)[0]
    if len(te_indices) >= 2:
        n0_te = neffs[te_indices[0]].real
        n1_te = neffs[te_indices[1]].real
        
        l_pi_te_val = abs(0.5 * lambda_c / (n0_te - n1_te))
        L_pi_TE.append(l_pi_te_val)
        valid_widths_te.append(w)

    # --- PROCESAMIENTO MODOS TM ---
    # Los modos TM tienen una fracción TE baja (te_fracs < 0.5)
    tm_indices = np.where(te_fracs < 0.5)[0]
    if len(tm_indices) >= 2:
        n0_tm = neffs[tm_indices[0]].real
        n1_tm = neffs[tm_indices[1]].real
        
        l_pi_tm_val = abs(0.5 * lambda_c / (n0_tm - n1_tm))
        L_pi_TM.append(l_pi_tm_val)
        valid_widths_tm.append(w)

# --- GENERACIÓN DE LA GRÁFICA ---
plt.figure(figsize=(10, 6))

# Plot TE
plt.plot(valid_widths_te, L_pi_TE, 'ro-', label='$L_\pi$ TE')

# Plot TM
plt.plot(valid_widths_tm, L_pi_TM, 'bs--', label='$L_\pi$ TM')

# Ajuste del eje X
plt.xticks(np.arange(5, 10.1, 0.5))

plt.xlabel("MMI Width (μm)")
plt.ylabel("$L_\pi$ (μm)")
plt.title("Longitud de batido $L_\pi$ vs Ancho del MMI (TE vs TM)")
plt.grid(True, which='both', linestyle='--', alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()
print(te_fracs)
print(tm_indices)
print(te_indices)
print(neffs)
print(n0_te - n1_te)
print(n0_tm- n1_tm)
# Out:
# 2026-04-30 17:18:25.641 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_2cc16b7ca9ffdda3.npz.
# 2026-04-30 17:18:25.644 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_5266d83ee722b523.npz.
# 2026-04-30 17:18:25.647 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_76f00aa2d341ea16.npz.
# 2026-04-30 17:18:25.648 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_dc7f594730171bb6.npz.
# 2026-04-30 17:18:25.650 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_51bee8c9c6f3cb01.npz.
# 2026-04-30 17:18:25.652 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_0e6424754e8c3042.npz.
# 2026-04-30 17:18:25.654 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_384b888d7ec6b927.npz.
# 2026-04-30 17:18:25.656 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_96739692158d550a.npz.
# 2026-04-30 17:18:25.658 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_cc10ee4616947e6f.npz.
# 2026-04-30 17:18:25.660 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_4fc874f251dab06c.npz.
# 2026-04-30 17:18:25.662 | INFO     | gplugins.tidy3d.modes:_data:266 - load data from .cache/Waveguide_8fa92fbb6a06489f.npz.
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:57: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\p'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# <>:54: SyntaxWarning: invalid escape sequence '\p'
# <>:57: SyntaxWarning: invalid escape sequence '\p'
# <>:63: SyntaxWarning: invalid escape sequence '\p'
# <>:64: SyntaxWarning: invalid escape sequence '\p'
# /tmp/ipykernel_895/1194977256.py:54: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(valid_widths_te, L_pi_TE, 'ro-', label='$L_\pi$ TE')
# /tmp/ipykernel_895/1194977256.py:57: SyntaxWarning: invalid escape sequence '\p'
#   plt.plot(valid_widths_tm, L_pi_TM, 'bs--', label='$L_\pi$ TM')
# /tmp/ipykernel_895/1194977256.py:63: SyntaxWarning: invalid escape sequence '\p'
#   plt.ylabel("$L_\pi$ (μm)")
# /tmp/ipykernel_895/1194977256.py:64: SyntaxWarning: invalid escape sequence '\p'
#   plt.title("Longitud de batido $L_\pi$ vs Ancho del MMI (TE vs TM)")
# [0.99998392 0.99993431 0.99984663 0.99971144 0.99950902 0.99918925
#  0.99853128 0.00229442 0.99212128 0.00214098 0.00830712 0.02924745
#  0.97493823 0.01302182 0.99080466 0.01122736 0.99945333 0.93601723
#  0.06829618 0.21225322]
# [ 7  9 10 11 13 15 18 19]
# [ 0  1  2  3  4  5  6  8 12 14 16 17]
# [1.67078682+8.10711934e-05j 1.66596209+8.15071241e-05j
#  1.65791584+8.22542235e-05j 1.64664524+8.33486845e-05j
#  1.63215836+8.48562397e-05j 1.61449586+8.69048842e-05j
#  1.59378873+8.97997022e-05j 1.57505364+1.68222418e-04j
#  1.57045974+9.49368449e-05j 1.57025654+1.68934611e-04j
#  1.5622402 +1.69767900e-04j 1.55123754+1.69945710e-04j
#  1.54596762+1.07726315e-04j 1.53688606+1.73346463e-04j
#  1.52817706+1.35218749e-04j 1.51955934+1.76617299e-04j
#  1.51901915+1.39569480e-04j 1.50354415+1.20636778e-04j
#  1.49941961+1.76709921e-04j 1.47859532+1.70099600e-04j]
# 0.004824737891126807
# 0.004797102124129982

# %% [markdown]
# # Grading
# - LO1 - 0.5 Point
# - LO2 - 1 Point
# - LO3 - 1 Point
# - LO4 - 1 Point
# - LO5 - 0.5 Point
# - LO6 - 1 Point
# - LO7 - 2 Points
# - E1-E4 - Up to 3 Points
